# %%
import pandas as pd

# %%
import numpy as np

# %%
coyoacan = pd.read_csv('coyoacan-catastro.csv')

# %%
coyoacan.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0           4110              575.00                   702.00
# 1           4100              518.05                   486.83
# 2           4110              247.00                     0.00
# 3           4100              995.00                  1173.64
# 4           4110              687.00                   604.00
#
#            uso_construccion clave_rango_nivel  anio_construccion  \
# 0              Habitacional                02             1980.0
# 1              Habitacional                05             2015.0
# 2                       NaN                01             2007.0
# 3  Habitacional y comercial                02             1980.0
# 4              Habitacional                05             1970.0
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí               5389.03   3098692.25
# 1                       Sí               5389.03   2791786.99
# ...

# %%
bj = pd.read_csv('benito-juarez-catastro.csv')

# %%
bj.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0           3400               122.0                    267.0
# 1           3400               110.0                     84.0
# 2           3400                99.0                    200.0
# 3           3400                96.0                    166.0
# 4           3400               101.0                    235.0
#
#   uso_construccion clave_rango_nivel  anio_construccion  \
# 0     Habitacional                02               1988
# 1     Habitacional                02               1970
# 2     Habitacional                02               1970
# 3     Habitacional                02               1970
# 4     Habitacional                05               1966
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí               5340.32    651519.04
# 1                       No               5340.32    587435.20
# ...

# %%
cuajimalpa = pd.read_csv('cuajimalpa-catastro.csv')

# %%
cuajimalpa.head()
# Out:
#   codigo_postal  superficie_terreno  superficie_construccion  \
# 0         01830              1594.0                    225.0
# 1         01830              3875.0                    172.0
# 2         05260               332.0                    293.0
# 3         05200               161.0                    294.0
# 4         05200                68.0                      0.0
#
#            uso_construccion clave_rango_nivel  anio_construccion  \
# 0                       NaN                02             1981.0
# 1                       NaN                01             2007.0
# 2  Habitacional y comercial                02             1967.0
# 3  Habitacional y comercial                05             2009.0
# 4  Habitacional y comercial                01             2007.0
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       No                196.31    312918.14
# 1                       No                196.31    760701.25
# ...

# %%
cuauh = pd.read_csv('cuauhtemoc-catastro.csv')

# %%
cuauh.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0           6060             3687.08                 10729.89
# 1           6060             1942.00                   343.18
# 2           6060             1942.00                   506.10
# 3           6060             1942.00                  4721.04
# 4           6060             1942.00                  4778.62
#
#   uso_construccion clave_rango_nivel  anio_construccion  \
# 0     Equipamiento                RU               1967
# 1     Equipamiento                10               1995
# 2     Equipamiento                10               1995
# 3     Equipamiento                10               1995
# 4     Equipamiento                10               1995
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí               9809.51  36168448.13
# 1                       Sí               9809.51  19054679.00
# ...

# %%
gustavomadero = pd.read_csv('gustavo-a-madero-catastro.csv')

# %%
gustavomadero.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0         7800.0               152.0                    455.0
# 1         7800.0               147.0                    208.0
# 2         7800.0               172.0                    244.0
# 3         7800.0                85.0                    186.0
# 4         7800.0               131.0                    224.0
#
#   uso_construccion  clave_rango_nivel  anio_construccion  \
# 0     Habitacional                  5               1966
# 1     Habitacional                  2               1968
# 2     Habitacional                  2               1970
# 3     Habitacional                  2               1971
# 4     Habitacional                  2               1971
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí               3138.07    476986.64
# 1                       No               3138.07    461296.29
# ...

# %%
iztacalco = pd.read_csv('iztacalco-catastro.csv')

# %%
iztacalco.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0           8200                34.0                    102.0
# 1           8200                87.0                    255.0
# 2           8200               155.0                    261.0
# 3           8200               162.0                    370.0
# 4           8200               159.0                    458.0
#
#   uso_construccion clave_rango_nivel  anio_construccion  \
# 0     Habitacional                05               1966
# 1     Habitacional                02               1977
# 2     Habitacional                02               1968
# 3     Habitacional                05               1997
# 4     Habitacional                05               1977
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí               3579.13    121690.42
# 1                       No               3579.13    311384.31
# ...

# %%
azcapo = pd.read_csv('azcapotzalco-catastro.csv')

# %%
azcapo.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0           2010              142.52                   352.33
# 1           2010              153.15                   199.21
# 2           2010              751.55                   687.56
# 3           2010              373.00                   255.00
# 4           2010              302.92                   324.03
#
#   uso_construccion clave_rango_nivel  anio_construccion  \
# 0     Habitacional                05               1973
# 1     Habitacional                02               1971
# 2     Habitacional                02               1966
# 3     Habitacional                02               1980
# 4     Habitacional                02               1998
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí               2354.24    335526.28
# 1                       No               2354.24    360551.86
# ...

# %%
xochi = pd.read_csv('xochimilco-catastro.csv')

# %%
xochi.head()
# Out:
#   codigo_postal  superficie_terreno  superficie_construccion uso_construccion  \
# 0         16790               390.0                    89.00     Áreas Verdes
# 1         16790               625.0                   285.00     Áreas Verdes
# 2         13546               720.5                   354.57     Áreas Verdes
# 3         16790               261.0                    96.00     Áreas Verdes
# 4         16790               185.0                    43.00     Áreas Verdes
#
#   clave_rango_nivel  anio_construccion instalaciones_especiales  \
# 0                02             1992.0                       No
# 1                02             1995.0                       No
# 2                02             1992.0                       No
# 3                02             1993.0                       No
# 4                02             1981.0                       No
#
#    valor_unitario_suelo  valor_suelo clave_valor_unitario_suelo  subsidio  \
# ...

# %%
venustiano_carranza = pd.read_csv('venustiano-carranza-catastro.csv')

# %%
venustiano_carranza.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0          15210               156.0                    210.0
# 1          15210               127.0                    250.0
# 2          15210                19.0                     64.0
# 3          15210                17.0                     59.0
# 4          15210                15.0                     52.0
#
#            uso_construccion clave_rango_nivel  anio_construccion  \
# 0  Habitacional y comercial                02               1971
# 1  Habitacional y comercial                02               1998
# 2  Habitacional y comercial                05               1967
# 3  Habitacional y comercial                05               1966
# 4  Habitacional y comercial                05               1966
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       No               3020.98    471272.88
# 1                       No               3020.98    383664.46
# ...

# %%
tlalpan = pd.read_csv('tlalpan-catastro.csv')

# %%
tlalpan.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0              0              396.89                   427.32
# 1          14738              244.00                   134.00
# 2          14738             1512.34                   377.00
# 3          14738              272.00                    71.00
# 4              0              322.00                    76.00
#
#   uso_construccion clave_rango_nivel  anio_construccion  \
# 0              NaN                02               1998
# 1              NaN                02               1997
# 2              NaN                05               1998
# 3              NaN                02               1998
# 4              NaN                02               1999
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       No                884.74    351144.46
# 1                       No                884.74    215876.56
# ...

# %%
tlahuac = pd.read_csv('tlahuac-catastro.csv')

# %%
tlahuac.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0          13720             1519.38                   524.69
# 1          12100              691.00                    76.00
# 2          13720              134.00                   134.00
# 3          13720              114.00                    53.00
# 4          13720              336.00                   105.00
#
#   uso_construccion  clave_rango_nivel  anio_construccion  \
# 0     Habitacional                  2             2000.0
# 1     Habitacional                  2             1969.0
# 2     Habitacional                  2             1990.0
# 3     Habitacional                  2             1989.0
# 4     Habitacional                  2             1984.0
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       No                694.75   1055589.25
# 1                       No                694.75    480072.25
# ...

# %%
milpa_alta = pd.read_csv('milpa-alta-catastro.csv')

# %%
milpa_alta.head()
# Out:
#   codigo_postal  superficie_terreno  superficie_construccion  \
# 0         12000               590.0                    134.0
# 1         12000               336.0                     98.0
# 2         12000               255.0                     60.0
# 3         12000               114.0                      0.0
# 4         12000               600.0                    206.0
#
#            uso_construccion  clave_rango_nivel  anio_construccion  \
# 0  Habitacional y comercial                  2             1995.0
# 1  Habitacional y comercial                  2             1984.0
# 2  Habitacional y comercial                  2             1992.0
# 3  Habitacional y comercial                  1             2007.0
# 4  Habitacional y comercial                  2             1982.0
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       No                689.78    406970.20
# 1                       No                689.78    231766.08
# ...

# %%
miguel_hidalgo = pd.read_csv('miguel-hidalgo-catastro.csv')

# %%
miguel_hidalgo.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0          11590              117.18                   105.62
# 1          11590              230.69                   279.84
# 2          11590              139.96                   265.96
# 3          11590              175.00                   424.00
# 4          11590              114.00                   241.00
#
#            uso_construccion clave_rango_nivel  anio_construccion  \
# 0  Habitacional y comercial                02             1980.0
# 1  Habitacional y comercial                05             1973.0
# 2  Habitacional y comercial                02             1966.0
# 3  Habitacional y comercial                05             1960.0
# 4  Habitacional y comercial                05             1966.0
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí              12719.62   1490485.07
# 1                       No              12249.17   2825761.03
# ...

# %%
magdalena_contreras =pd.read_csv('magdalena-contreras-catastro.csv')

# %%
magdalena_contreras.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0           1080              220.35                   301.01
# 1           1080              136.00                   165.00
# 2           1080               24.00                    83.00
# 3           1080               24.00                    83.00
# 4           1080               28.00                    97.00
#
#            uso_construccion clave_rango_nivel  anio_construccion  \
# 0  Habitacional y comercial                02             1991.0
# 1  Habitacional y comercial                02             1968.0
# 2  Habitacional y comercial                05             1965.0
# 3  Habitacional y comercial                05             1965.0
# 4  Habitacional y comercial                05             1966.0
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       No               3619.89    797642.76
# 1                       No               3619.89    492305.04
# ...

# %%
iztapalapa = pd.read_csv('iztapalapa-catastro.csv')

# %%
iztapalapa.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0           9440              307.81                   395.05
# 1           9490             1049.17                   755.29
# 2           9490              411.56                   439.59
# 3           9440              246.00                   198.00
# 4           9490             1446.98                   692.86
#
#            uso_construccion clave_rango_nivel  anio_construccion  \
# 0  Habitacional y comercial                02             1985.0
# 1  Habitacional y comercial                02             1977.0
# 2  Habitacional y comercial                02             1974.0
# 3  Habitacional y comercial                02             1970.0
# 4  Habitacional y comercial                02             1966.0
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí                3002.2    924107.18
# 1                       No                3002.2   3149818.17
# ...

# %%
alvaro_obregon = pd.read_csv('alvaro-obregon-catastro.csv')

# %%
alvaro_obregon.head()
# Out:
#    codigo_postal  superficie_terreno  superficie_construccion  \
# 0           1120            12276.00                  2452.08
# 1           1120            12276.00                  8763.97
# 2           1120            12276.00                  8294.69
# 3           1120               89.14                   178.20
# 4           1120               66.74                   134.31
#
#   uso_construccion clave_rango_nivel  anio_construccion  \
# 0              NaN                02             2018.0
# 1              NaN                99             2018.0
# 2              NaN                99             2018.0
# 3     Habitacional                05             1968.0
# 4     Habitacional                05             1973.0
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí               2400.71  29470252.00
# 1                       Sí               2400.71  29470252.00
# ...

# %%
a2 = coyoacan.append(bj)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/231809348.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a2 = coyoacan.append(bj)

# %%
a3 = a2.append(cuajimalpa)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/4003663115.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a3 = a2.append(cuajimalpa)

# %%
a4 =a3.append(cuauh)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/3253120358.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a4 =a3.append(cuauh)

# %%
a5 = a4.append(gustavomadero)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/4060878770.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a5 = a4.append(gustavomadero)

# %%
a6 = a5.append(iztacalco)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/1745232570.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a6 = a5.append(iztacalco)

# %%
a7 = a6.append(azcapo)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/3815678196.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a7 = a6.append(azcapo)

# %%
a8 = a7.append(xochi)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/42837493.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a8 = a7.append(xochi)

# %%
a9 = a8.append(venustiano_carranza)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/1341745934.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a9 = a8.append(venustiano_carranza)

# %%
a10 = a9.append(tlalpan)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/1612963988.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a10 = a9.append(tlalpan)

# %%
a11 = a10.append(tlahuac)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/443624429.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a11 = a10.append(tlahuac)

# %%
a12= a11.append(milpa_alta)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/1045475757.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a12= a11.append(milpa_alta)

# %%
a13 = a12.append(miguel_hidalgo)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/749694267.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a13 = a12.append(miguel_hidalgo)

# %%
a14 = a13.append(magdalena_contreras)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/4186861634.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a14 = a13.append(magdalena_contreras)

# %%
a15 = a14.append(iztapalapa)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/197123564.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a15 = a14.append(iztapalapa)

# %%
catastro = a15.append(alvaro_obregon)
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_7575/2221410181.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catastro = a15.append(alvaro_obregon)

# %%
catastro['alcaldia'].unique()
# Out:
# array(['COYOACAN', nan, 'BENITO JUAREZ', 'CUAJIMALPA DE MORELOS',
#        'CUAUHTEMOC', 'GUSTAVO A. MADERO', 'IZTACALCO', 'AZCAPOTZALCO',
#        'XOCHIMILCO', 'VENUSTIANO CARRANZA', 'TLALPAN', 'TLAHUAC',
#        'MILPA ALTA', 'MIGUEL HIDALGO', 'LA MAGDALENA CONTRERAS',
#        'IZTAPALAPA', 'ALVARO OBREGON'], dtype=object)

# %%
catastro.shape
# Out:
# (120619, 15)

# %% [markdown]
# # DATA MANIPULATION

# %%
catastro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120619 entries, 0 to 7071
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   codigo_postal               120613 non-null  object
#  1   superficie_terreno          120619 non-null  float64
#  2   superficie_construccion     120618 non-null  float64
#  3   uso_construccion            118300 non-null  object
#  4   clave_rango_nivel           120610 non-null  object
#  5   anio_construccion           120587 non-null  float64
#  6   instalaciones_especiales    120616 non-null  object
#  7   valor_unitario_suelo        120581 non-null  float64
#  8   valor_suelo                 120384 non-null  float64
#  9   clave_valor_unitario_suelo  120580 non-null  object
#  10  subsidio                    120613 non-null  float64
#  11  latitud                     120612 non-null  float64
# ...

# %% [markdown]
# ## Valor catastro por año

# %% [markdown]
# **CATASTRO TO CSV

# %%
catastro.to_csv('catastro_emilito.csv')

# %%
valor_catastro = pd.read_csv('catastro_editar 2.csv')
# Out:
# /var/folders/8s/vcwxyvv93jlbc3gkwsvl2xtm0000gn/T/ipykernel_20156/855255331.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   valor_catastro = pd.read_csv('catastro_editar 2.csv')

# %%
valor_catastro['alcaldia'].unique()
# Out:
# array(['COYOACAN', nan, 'BENITO JUAREZ', 'CUAJIMALPA DE MORELOS',
#        'CUAUHTEMOC', 'GUSTAVO A. MADERO', 'IZTACALCO', 'AZCAPOTZALCO',
#        'XOCHIMILCO', 'VENUSTIANO CARRANZA', 'TLALPAN', 'TLAHUAC',
#        'MILPA ALTA', 'MIGUEL HIDALGO', 'LA MAGDALENA CONTRERAS',
#        'IZTAPALAPA', 'ALVARO OBREGON'], dtype=object)

# %%
valor_catastro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120619 entries, 0 to 120618
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Unnamed: 0                  120619 non-null  int64
#  1   codigo_postal               120613 non-null  object
#  2   superficie_terreno          120619 non-null  float64
#  3   superficie_construccion     120618 non-null  float64
#  4   uso_construccion            118300 non-null  object
#  5   clave_rango_nivel           120610 non-null  object
#  6   anio_construccion           120587 non-null  float64
#  7   instalaciones_especiales    120616 non-null  object
#  8   valor_unitario_suelo        120581 non-null  float64
#  9   valor_suelo                 120384 non-null  float64
#  10  clave_valor_unitario_suelo  120580 non-null  object
#  11  subsidio                    120613 non-null  float64
# ...

# %%
valor_catastro['anio_construccion']=valor_catastro['anio_construccion'].astype(str)

# %%
valor_catastro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120619 entries, 0 to 120618
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Unnamed: 0                  120619 non-null  int64
#  1   codigo_postal               120613 non-null  object
#  2   superficie_terreno          120619 non-null  float64
#  3   superficie_construccion     120618 non-null  float64
#  4   uso_construccion            118300 non-null  object
#  5   clave_rango_nivel           120610 non-null  object
#  6   anio_construccion           120619 non-null  object
#  7   instalaciones_especiales    120616 non-null  object
#  8   valor_unitario_suelo        120581 non-null  float64
#  9   valor_suelo                 120384 non-null  float64
#  10  clave_valor_unitario_suelo  120580 non-null  object
#  11  subsidio                    120613 non-null  float64
# ...

# %%
valor_catastro.shape
# Out:
# (120619, 16)

# %%
valor_catastro = valor_catastro[(valor_catastro['uso_construccion']=='Habitacional') | (valor_catastro['uso_construccion']== 'Habitacional y comercial')]

# %%
valor_catastro.shape
# Out:
# (111852, 16)

# %%
valor_catastro.head()
# Out:
#    Unnamed: 0 codigo_postal  superficie_terreno  superficie_construccion  \
# 0           0          4110              575.00                   702.00
# 1           1          4100              518.05                   486.83
# 3           3          4100              995.00                  1173.64
# 4           4          4110              687.00                   604.00
# 5           5          4100              262.17                   336.85
#
#            uso_construccion clave_rango_nivel anio_construccion  \
# 0              Habitacional                02            1980.0
# 1              Habitacional                05            2015.0
# 3  Habitacional y comercial                02            1980.0
# 4              Habitacional                05            1970.0
# 5              Habitacional                02            1972.0
#
#   instalaciones_especiales  valor_unitario_suelo  valor_suelo  \
# 0                       Sí               5389.03   3098692.25
# ...

# %%
valor_catastro['alcaldia'].unique()
# Out:
# array(['COYOACAN', 'BENITO JUAREZ', nan, 'CUAJIMALPA DE MORELOS',
#        'CUAUHTEMOC', 'GUSTAVO A. MADERO', 'IZTACALCO', 'AZCAPOTZALCO',
#        'XOCHIMILCO', 'VENUSTIANO CARRANZA', 'TLALPAN', 'TLAHUAC',
#        'MILPA ALTA', 'MIGUEL HIDALGO', 'LA MAGDALENA CONTRERAS',
#        'IZTAPALAPA', 'ALVARO OBREGON'], dtype=object)

# %%
valor_catastro_por_ano = valor_catastro.groupby(['alcaldia','anio_construccion'],as_index=False)['valor_unitario_suelo'].mean()

# %%
valor_catastro_por_ano.head(5)
# Out:
#          alcaldia anio_construccion  valor_unitario_suelo
# 0  ALVARO OBREGON            1922.0               1659.02
# 1  ALVARO OBREGON            1936.0               1499.73
# 2  ALVARO OBREGON            1941.0               1659.02
# 3  ALVARO OBREGON            1950.0               1659.02
# 4  ALVARO OBREGON            1951.0               2400.71

# %% [markdown]
# ** promedio de el valor del suelo habitacional por año y por alcaldia

# %%
valor_catastro_por_ano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153 entries, 0 to 1152
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   alcaldia              1153 non-null   object
#  1   anio_construccion     1153 non-null   object
#  2   valor_unitario_suelo  1153 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 27.1+ KB

# %%
valor_catastro_por_ano['anio_construccion']=valor_catastro_por_ano['anio_construccion'].astype(float)

# %%
valor_catastro_por_ano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153 entries, 0 to 1152
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   alcaldia              1153 non-null   object
#  1   anio_construccion     1145 non-null   float64
#  2   valor_unitario_suelo  1153 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 27.1+ KB

# %%
valor_catastro_por_ano.head(50)
# Out:
#           alcaldia  anio_construccion  valor_unitario_suelo
# 0   ALVARO OBREGON             1922.0           1659.020000
# 1   ALVARO OBREGON             1936.0           1499.730000
# 2   ALVARO OBREGON             1941.0           1659.020000
# 3   ALVARO OBREGON             1950.0           1659.020000
# 4   ALVARO OBREGON             1951.0           2400.710000
# 5   ALVARO OBREGON             1952.0           1968.310000
# 6   ALVARO OBREGON             1953.0           2659.250000
# 7   ALVARO OBREGON             1954.0           1659.020000
# 8   ALVARO OBREGON             1955.0           1730.163333
# 9   ALVARO OBREGON             1956.0           1989.555000
# 10  ALVARO OBREGON             1957.0           2400.710000
# 11  ALVARO OBREGON             1959.0           1968.310000
# 12  ALVARO OBREGON             1960.0           1840.161667
# 13  ALVARO OBREGON             1961.0           1909.782500
# 14  ALVARO OBREGON             1962.0           2237.400000
# ...

# %%
#valor_catastro_por_ano = valor_catastro_por_ano[valor_catastro_por_ano.anio_construccion != 0]

# %%
valor_catastro_por_ano.to_csv('valor_catastro_por_ano.csv')
