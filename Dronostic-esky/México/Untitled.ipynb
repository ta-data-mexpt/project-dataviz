# %%
#importing libraries
import numpy as np
import pandas as pd
from pandas import DataFrame,read_csv

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Passing Mexico city temperature csv file into a DataFrame
#file = pd.read_csv("/Users/polly/Documents/Ironhack/Dronostic-esky/México/Temperatura Ciudad de México.csv")
file=r'Temperatura_CDMX.csv'
CDMX= pd.read_csv(file)

#Adding the moving averages for Mexico city, Temperatures
Temperatura_CDMX['moving_temp'] = Temperatura_CDMX.avg_temp.rolling(window=20).mean() 

Temperatura_CDMX
# Out:
#       Año            Ciudad    País  avg_temp  moving_temp
# 0    1849  Ciudad de Mexico  Mexico     20.11          NaN
# 1    1850  Ciudad de Mexico  Mexico     21.09          NaN
# 2    1851  Ciudad de Mexico  Mexico     22.13          NaN
# 3    1852  Ciudad de Mexico  Mexico     20.59          NaN
# 4    1853  Ciudad de Mexico  Mexico     22.04          NaN
# ..    ...               ...     ...       ...          ...
# 168  2017  Ciudad de Mexico  Mexico     10.01      20.2620
# 169  2018  Ciudad de Mexico  Mexico     15.40      19.9775
# 170  2019  Ciudad de Mexico  Mexico     16.20      19.6810
# 171  2020  Ciudad de Mexico  Mexico     23.01      19.8020
# 172  2021  Ciudad de Mexico  Mexico     22.45      19.8225
#
# [173 rows x 5 columns]

# %%
#Creating a line chart for Mexico city Temperatures in moving avg

plt.plot(CDMX.Año,CDMX.moving_temp)
plt.title('Ciudad de Mexico Temperatures Moving Averages')
plt.ylabel('Temperatures')
plt.xlabel('Year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-52e0836af028> in <module>
#       1 #Creating a line chart for Mexico city Temperatures in moving avg
#       2
# ----> 3 plt.plot(CDMX.Año,CDMX.moving_temp)
#       4 plt.title('Ciudad de Mexico Temperatures Moving Averages')
#       5 plt.ylabel('Temperatures')
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'moving_temp'
