# %%
import requests

# %%
champs_json = requests.get('http://ddragon.leagueoflegends.com/cdn/10.9.1/data/es_MX/champion.json')
champs = champs_json.json()
# accedemos a la base de datos de campeones

# %%
import pandas as pd
champs
# Out:
# {'type': 'champion',
#  'format': 'standAloneComplex',
#  'version': '10.9.1',
#  'data': {'Aatrox': {'version': '10.9.1',
#    'id': 'Aatrox',
#    'key': '266',
#    'name': 'Aatrox',
#    'title': 'la Espada Darkin',
#    'blurb': 'Aatrox y sus hermanos, que alguna vez fueron respetados defensores de Shurima contra el Vacío, se convirtieron en una amenaza aún mayor para Runaterra y los derrotaron con hechicería mortal usada con astucia. Pero, después de siglos de encarcelamiento...',
#    'info': {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4},
#    'image': {'full': 'Aatrox.png',
#     'sprite': 'champion0.png',
#     'group': 'champion',
#     'x': 0,
#     'y': 0,
#     'w': 48,
#     'h': 48},
#    'tags': ['Fighter', 'Tank'],
#    'partype': 'Pozo Sangriento',
#    'stats': {'hp': 580,
#     'hpperlevel': 90,
#     'mp': 0,
#     'mpperlevel': 0,
#     'movespeed': 345,
#     'armor': 38,
#     'armorperlevel': 3.25,
#     'spellblock': 32.1,
# ...

# %%
len(champs['data'])
# Cantidad de Campeones
# Out:
# 148

# %%
summoner_json = requests.get('https://la1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Sharp%20Demon?api_key=RGAPI-708e6448-7d2b-4a36-a654-d78ee3db636c')
summoner = summoner_json.json()
# Accedemos a los datos de usuario

# %%
summoner
# datos de invocador(jugador)
# Out:
# {'id': 'rtc9if6FHYgfr3Owu_xwXCzV3MiTrVTQwU6yP8c943AczQ',
#  'accountId': 'jF9QdLbzTu25BgQd2Yurpx7NlhYGjyt8zARJu-bylIcy',
#  'puuid': '_6AGekMpI_CONpl4TZCfPrVaZEFyG4MmFCIiz1GysB_aAFI1y6dDolbLnAnBelvOx5T_hjp7kax3iA',
#  'name': 'Sharp Demon',
#  'profileIconId': 25,
#  'revisionDate': 1589151098000,
#  'summonerLevel': 135}

# %%
# obtenemos los campeones existentes en el juego
campeones = []
print(type(champs['data']))
for i in champs['data']:
    campeones.append(i)
# Out:
# <class 'dict'>

# %%
campeones
# Out:
# ['Aatrox',
#  'Ahri',
#  'Akali',
#  'Alistar',
#  'Amumu',
#  'Anivia',
#  'Annie',
#  'Aphelios',
#  'Ashe',
#  'AurelionSol',
#  'Azir',
#  'Bard',
#  'Blitzcrank',
#  'Brand',
#  'Braum',
#  'Caitlyn',
#  'Camille',
#  'Cassiopeia',
#  'Chogath',
#  'Corki',
#  'Darius',
#  'Diana',
#  'Draven',
#  'DrMundo',
#  'Ekko',
#  'Elise',
#  'Evelynn',
#  'Ezreal',
#  'Fiddlesticks',
#  'Fiora',
#  'Fizz',
#  'Galio',
#  'Gangplank',
#  'Garen',
#  'Gnar',
#  'Gragas',
#  'Graves',
#  'Hecarim',
#  'Heimerdinger',
#  'Illaoi',
#  'Irelia',
#  'Ivern',
#  'Janna',
#  'JarvanIV',
#  'Jax',
#  'Jayce',
#  'Jhin',
#  'Jinx',
#  'Kaisa',
#  'Kalista',
#  'Karma',
#  'Karthus',
#  'Kassadin',
#  'Katarina',
#  'Kayle',
#  'Kayn',
#  'Kennen',
#  'Khazix',
#  'Kindred',
#  'Kled',
#  'KogMaw',
#  'Leblanc',
#  'LeeSin',
#  'Leona',
#  'Lissandra',
#  'Lucian',
#  'Lulu',
#  'Lux',
#  'Malphite',
#  'Malzahar',
#  'Maokai',
#  'MasterYi',
#  'MissFortune',
#  'MonkeyKing',
#  'Mordekaiser',
# ...

# %%
champs['data'].keys()
# Out:
# dict_keys(['Aatrox', 'Ahri', 'Akali', 'Alistar', 'Amumu', 'Anivia', 'Annie', 'Aphelios', 'Ashe', 'AurelionSol', 'Azir', 'Bard', 'Blitzcrank', 'Brand', 'Braum', 'Caitlyn', 'Camille', 'Cassiopeia', 'Chogath', 'Corki', 'Darius', 'Diana', 'Draven', 'DrMundo', 'Ekko', 'Elise', 'Evelynn', 'Ezreal', 'Fiddlesticks', 'Fiora', 'Fizz', 'Galio', 'Gangplank', 'Garen', 'Gnar', 'Gragas', 'Graves', 'Hecarim', 'Heimerdinger', 'Illaoi', 'Irelia', 'Ivern', 'Janna', 'JarvanIV', 'Jax', 'Jayce', 'Jhin', 'Jinx', 'Kaisa', 'Kalista', 'Karma', 'Karthus', 'Kassadin', 'Katarina', 'Kayle', 'Kayn', 'Kennen', 'Khazix', 'Kindred', 'Kled', 'KogMaw', 'Leblanc', 'LeeSin', 'Leona', 'Lissandra', 'Lucian', 'Lulu', 'Lux', 'Malphite', 'Malzahar', 'Maokai', 'MasterYi', 'MissFortune', 'MonkeyKing', 'Mordekaiser', 'Morgana', 'Nami', 'Nasus', 'Nautilus', 'Neeko', 'Nidalee', 'Nocturne', 'Nunu', 'Olaf', 'Orianna', 'Ornn', 'Pantheon', 'Poppy', 'Pyke', 'Qiyana', 'Quinn', 'Rakan', 'Rammus', 'RekSai', 'Renekton', 'Rengar', 'Riven', 
# ...

# %%
type(champs)
# Out:
# dict

# %%
champs.keys()
# Out:
# dict_keys(['type', 'format', 'version', 'data'])

# %%
champs['data']['Aatrox']['title']
# Out:
# 'la Espada Darkin'

# %%
# obtenemos los titulos del campeón
titulos = []
for i in campeones:
    #print(champs['data'][i]['title'])    
    titulos.append(champs['data'][i]['title'])

# %%
titulos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3ea22fb8486c> in <module>
# ----> 1 titulos
#
# NameError: name 'titulos' is not defined

# %%
camp_titulos = []
for i,j in enumerate(campeones):
    # j + '\n' + titulos[i]
    # print(camp_titulos)
    camp_titulos.append(j + '-' + titulos[i] + '.')
print(camp_titulos[0])
print(len(camp_titulos))
# Out:
# Aatrox-la Espada Darkin.
# 148

# %%
names_camp = ['Campeón']
df_camp = pd.DataFrame(camp_titulos, columns=names_camp)
df_camp
# Out:
#                                Campeón
# 0             Aatrox-la Espada Darkin.
# 1      Ahri-la Vastaya de Nueve Colas.
# 2            Akali-la Asesina Furtiva.
# 3                Alistar-el Minotauro.
# 4               Amumu-la Momia Triste.
# ..                                 ...
# 143     Zed-el Maestro de las Sombras.
# 144  Ziggs-el Experto en Hexplosivos .
# 145     Zilean-el Guardián del Tiempo.
# 146     Zoe-el Aspecto del Crepúsculo.
# 147  Zyra-el Despertar de las Espinas.
#
# [148 rows x 1 columns]

# %%
# obtenemos los basic stats de los campeones
# basic_stats = {}
basic_stats = []
for i in campeones:
    #print(champs['data'][i]['info'])
    basic_stats.append(champs['data'][i]['info'])
basic_stats[0]
# Out:
# {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4}

# %%
df_stats = pd.DataFrame(basic_stats)
df_stats
# Out:
#      attack  defense  magic  difficulty
# 0         8        4      3           4
# 1         3        4      8           5
# 2         5        3      8           7
# 3         6        9      5           7
# 4         2        6      8           3
# ..      ...      ...    ...         ...
# 143       9        2      1           7
# 144       2        4      9           4
# 145       2        5      8           6
# 146       1        7      8           5
# 147       4        3      8           7
#
# [148 rows x 4 columns]

# %%
# Concatenando DataFrames
table1 = pd.concat([df_camp,df_stats], axis = 1)
table1
# Out:
#                                Campeón  attack  defense  magic  difficulty
# 0             Aatrox-la Espada Darkin.       8        4      3           4
# 1      Ahri-la Vastaya de Nueve Colas.       3        4      8           5
# 2            Akali-la Asesina Furtiva.       5        3      8           7
# 3                Alistar-el Minotauro.       6        9      5           7
# 4               Amumu-la Momia Triste.       2        6      8           3
# ..                                 ...     ...      ...    ...         ...
# 143     Zed-el Maestro de las Sombras.       9        2      1           7
# 144  Ziggs-el Experto en Hexplosivos .       2        4      9           4
# 145     Zilean-el Guardián del Tiempo.       2        5      8           6
# 146     Zoe-el Aspecto del Crepúsculo.       1        7      8           5
# 147  Zyra-el Despertar de las Espinas.       4        3      8           7
#
# [148 rows x 5 columns]

# %%
# obtenemos un diccionario de campeones con sus stats
champ_title = {}
for i,j in enumerate(campeones):
    #print(i)
    #print(j)
    champ_title[j] = titulos[i]

# %%
#champ_title

# %%
# obtenemos un diccionario de campeones con sus stats
champ_info = {}
for i,j in enumerate(campeones):
    #print(i)
    #print(j)
    champ_info[j] = champs['data'][j]['info']
#champ_info

# %%
#---------------------------------------------------------------------------------------------

# %%
camp_titulos[0]
# Out:
# 'Aatrox-la Espada Darkin.'

# %%
basic_stats
# Out:
# [{'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4},
#  {'attack': 3, 'defense': 4, 'magic': 8, 'difficulty': 5},
#  {'attack': 5, 'defense': 3, 'magic': 8, 'difficulty': 7},
#  {'attack': 6, 'defense': 9, 'magic': 5, 'difficulty': 7},
#  {'attack': 2, 'defense': 6, 'magic': 8, 'difficulty': 3},
#  {'attack': 1, 'defense': 4, 'magic': 10, 'difficulty': 10},
#  {'attack': 2, 'defense': 3, 'magic': 10, 'difficulty': 6},
#  {'attack': 6, 'defense': 2, 'magic': 1, 'difficulty': 10},
#  {'attack': 7, 'defense': 3, 'magic': 2, 'difficulty': 4},
#  {'attack': 2, 'defense': 3, 'magic': 8, 'difficulty': 7},
#  {'attack': 6, 'defense': 3, 'magic': 8, 'difficulty': 9},
#  {'attack': 4, 'defense': 4, 'magic': 5, 'difficulty': 9},
#  {'attack': 4, 'defense': 8, 'magic': 5, 'difficulty': 4},
#  {'attack': 2, 'defense': 2, 'magic': 9, 'difficulty': 4},
#  {'attack': 3, 'defense': 9, 'magic': 4, 'difficulty': 3},
#  {'attack': 8, 'defense': 2, 'magic': 2, 'difficulty': 6},
# ...

# %%
# Aquí obtenemos la lista del campeón con ESTADÍSTICAS BÁSICAS
info_champ = list(zip(camp_titulos,basic_stats))
#list(info_champ)
info_champ[0]
# Out:
# ('Aatrox-la Espada Darkin.',
#  {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4})

# %%
# obtenemos el ROL de cada campeón
tags = []
for i in campeones:
    #print(champs['data'][i]['tags'])
    tags.append(champs['data'][i]['tags'])
    #print(type(champs['data'][i]['tags']))
tagcols=['Rol1','Rol2']
df_tag = pd.DataFrame(tags, columns=tagcols)
df_tag
# Out:
#          Rol1      Rol2
# 0     Fighter      Tank
# 1        Mage  Assassin
# 2    Assassin      None
# 3        Tank   Support
# 4        Tank      Mage
# ..        ...       ...
# 143  Assassin      None
# 144      Mage      None
# 145   Support      Mage
# 146      Mage   Support
# 147      Mage   Support
#
# [148 rows x 2 columns]

# %%
# ------------------------------------------------------------------------------------------------------------------------
names_camp = ['Champion']
basic_table = pd.DataFrame(campeones, columns=names_camp)
basic_table = pd.concat([basic_table,df_stats], axis = 1)
basic_table = pd.concat([basic_table,df_skins], axis = 1)
basic_table = pd.concat([basic_table,df_tag], axis = 1)
basic_table
# Out:
#     Champion  attack  defense  magic  difficulty  Popularity by Skins  \
# 0     Aatrox       8        4      3           4                    7
# 1       Ahri       3        4      8           5                   12
# 2      Akali       5        3      8           7                   13
# 3    Alistar       6        9      5           7                   14
# 4      Amumu       2        6      8           3                   11
# ..       ...     ...      ...    ...         ...                  ...
# 143      Zed       9        2      1           7                    7
# 144    Ziggs       2        4      9           4                    9
# 145   Zilean       2        5      8           6                    7
# 146      Zoe       1        7      8           5                    4
# 147     Zyra       4        3      8           7                    7
#
#          Rol1      Rol2
# 0     Fighter      Tank
# 1        Mage  Assassin
# 2    Assassin      None
# 3        Tank   Support
# ...

# %%
basic_table.to_csv(r'Basic_table.csv')

# %%
#------------------------------------------------------------------------------------------------------------------------------

# %%
# añadiremos el rol principal de cada campeón
tabl_champs = list(zip(info_champ,tags))
tabl_champs[0]
#print(len(tabl_champs))
# Out:
# (('Aatrox-la Espada Darkin.',
#   {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4}),
#  ['Fighter', 'Tank'])

# %%
basic_table = list(zip(basic_table,tags))
basic_table
# Out:
# [('Campeón', ['Fighter', 'Tank']),
#  ('attack', ['Mage', 'Assassin']),
#  ('defense', ['Assassin']),
#  ('magic', ['Tank', 'Support']),
#  ('difficulty', ['Tank', 'Mage'])]

# %%
#campeones

# %%
# buscaremos la popularidad de un campeón mediante el número de 'skins' que tiene
# el campo de skins no se encuentra en la URL anteriror ocupada
# se debe entrar en 'http://ddragon.leagueoflegends.com/cdn/10.9.1/data/es_MX/champion/<champion_name>.json'
url_champ = []
for i in campeones:
    #print('http://ddragon.leagueoflegends.com/cdn/10.9.1/data/es_MX/champion/%s.json'%(i))
    url_champ.append('http://ddragon.leagueoflegends.com/cdn/10.9.1/data/es_MX/champion/%s.json'%(i))
url_champ[1]
# Out:
# 'http://ddragon.leagueoflegends.com/cdn/10.9.1/data/es_MX/champion/Ahri.json'

# %%
# accedemos a la base de datos de cada campeón y guardamos el json
chracters_json = []
for i in url_champ:
    personaje_get = requests.get(i)
    campion_info = personaje_get.json()
    # print(champs['data'][i]['skins'])
    chracters_json.append(campion_info)

# %%
skins_per_character = []
count = 0
for i in chracters_json:
    for j in campeones:
        #print(i)
        #print(j)
        try:
            print(len(i['data'][j]['skins']))
            print(i['data'][j]['skins'])
            count += 1
        except:
            pass
        break
# Out:
# 7
# [{'id': '266000', 'num': 0, 'name': 'default', 'chromas': False}, {'id': '266001', 'num': 1, 'name': 'Aatrox Justiciero', 'chromas': False}, {'id': '266002', 'num': 2, 'name': 'Aatrox Mecha', 'chromas': True}, {'id': '266003', 'num': 3, 'name': 'Aatrox Cazador Marino', 'chromas': False}, {'id': '266007', 'num': 7, 'name': 'Aatrox Luna de Sangre', 'chromas': False}, {'id': '266008', 'num': 8, 'name': 'Aatrox Luna de Sangre Edición Prestigiosa', 'chromas': False}, {'id': '266009', 'num': 9, 'name': 'Aatrox Victorioso', 'chromas': True}]

# %%
# Faltara implementar los nombres de cada skin
skins_per_character = []
#skins_name = []
#count = 0
for i in chracters_json:
    for j in campeones:
        #print(i)
        #print(j)
        try:
            #print(len(i['data'][j]['skins']))
            skins_per_character.append(len(i['data'][j]['skins']))
            #print(i['data'][j]['skins'][count]['name'])
            #count += 1
        except:
            pass

# %%
# -----------------------------------DataFrame para mostrar
col_skins = ['Popularity by Skins']
df_skins = pd.DataFrame(skins_per_character, columns = col_skins)
# Concatenando DataFrame de popularidad
table2 = pd.concat([table1,df_skins], axis = 1)
table2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-46891db75671> in <module>
#       3 df_skins = pd.DataFrame(skins_per_character, columns = col_skins)
#       4 # Concatenando DataFrame de popularidad
# ----> 5 table2 = pd.concat([table1,df_skins], axis = 1)
#       6 table2
#
# NameError: name 'table1' is not defined

# %%
table3 = pd.concat([table2,df_tag], axis = 1)
table3
# Out:
#                                Campeón  attack  defense  magic  difficulty  \
# 0    Aatrox-la Espada Darkin.           8       4        3      4
# 1    Ahri-la Vastaya de Nueve Colas.    3       4        8      5
# 2    Akali-la Asesina Furtiva.          5       3        8      7
# 3    Alistar-el Minotauro.              6       9        5      7
# 4    Amumu-la Momia Triste.             2       6        8      3
# ..                      ...            ..      ..       ..     ..
# 143  Zed-el Maestro de las Sombras.     9       2        1      7
# 144  Ziggs-el Experto en Hexplosivos .  2       4        9      4
# 145  Zilean-el Guardián del Tiempo.     2       5        8      6
# 146  Zoe-el Aspecto del Crepúsculo.     1       7        8      5
# 147  Zyra-el Despertar de las Espinas.  4       3        8      7
#
#      Popularidad by Skins      Rol1      Rol2
# 0    7                     Fighter   Tank
# 1    12                    Mage      Assassin
# ...

# %%
table3.to_csv(r'Basic_info.csv')

# %%
binaries_assets[10]

# %%
chracters_json[0]['data']['Aatrox']['skins'][1]['name']
# Out:
# 'Aatrox Justiciero'

# %%
#-------------------------formatos JSON
#print(len(chracters_json[0]['data']['Aatrox']['skins']))
chracters_json[0]['data']['Aatrox']['skins']
# Out:
# [{'id': '266000', 'num': 0, 'name': 'default', 'chromas': False},
#  {'id': '266001', 'num': 1, 'name': 'Aatrox Justiciero', 'chromas': False},
#  {'id': '266002', 'num': 2, 'name': 'Aatrox Mecha', 'chromas': True},
#  {'id': '266003', 'num': 3, 'name': 'Aatrox Cazador Marino', 'chromas': False},
#  {'id': '266007', 'num': 7, 'name': 'Aatrox Luna de Sangre', 'chromas': False},
#  {'id': '266008',
#   'num': 8,
#   'name': 'Aatrox Luna de Sangre Edición Prestigiosa',
#   'chromas': False},
#  {'id': '266009', 'num': 9, 'name': 'Aatrox Victorioso', 'chromas': True}]

# %%
# añadiremos el número de skins existentes a cada campeón
tabl_champs_skins = list(zip(tabl_champs,skins_per_character))
tabl_champs_skins[0]
#print(len(tabl_champs))
# Out:
# ((('Aatrox-la Espada Darkin.',
#    {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4}),
#   ['Fighter', 'Tank']),
#  7)

# %%
colnames = ['Campeón','Basic_Stats','Polularidad-Skins']
#df = pd.DataFrame(tabl_champs_skins, columns=colnames)
df = pd.DataFrame(tabl_champs_skins)

# %%
#---------------------Tratando de obtener las imágens y mostrarlas
# vamos a obtener una pequeña imagen del campeon
# el pequeño asset se encuentra en 'http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/<champion_name>.png'
from IPython.display import Image
url_assets = []
asset_prueba = requests.get('http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Aatrox.png')

#print(type(asset_prueba.content))
#print(asset_prueba.content)
# Out:
# <class 'bytes'>
# ...

# %%
binaries_assets = []
for i in url_assets:
    asset_proof = requests.get(i)
    content_asset = asset_proof.content
    display_img = Image(content_asset)
    binaries_assets.append(display_img)

# %%
binaries_assets[1]

# %%
df_binaries = pd.DataFrame(binaries_assets)
# Out:
#                                        0
# 0    <IPython.core.display.Image object>
# 1    <IPython.core.display.Image object>
# 2    <IPython.core.display.Image object>
# 3    <IPython.core.display.Image object>
# 4    <IPython.core.display.Image object>
# ..                                   ...
# 143  <IPython.core.display.Image object>
# 144  <IPython.core.display.Image object>
# 145  <IPython.core.display.Image object>
# 146  <IPython.core.display.Image object>
# 147  <IPython.core.display.Image object>
#
# [148 rows x 1 columns]

# %%
Image(asset_prueba.content)

# %%
a = [Image(asset_prueba.content)]
b = Image(asset_prueba.content)
print (a)
# Out:
# [<IPython.core.display.Image object>]

# %%
display(b)

# %%
display('http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Aatrox.png')
# Out:
# 'http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Aatrox.png'

# %%
img = pd.DataFrame(a)
img
# Out:
#                                      0
# 0  <IPython.core.display.Image object>

# %%
url_assets = []
for i in campeones:
    #print('http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/%s.png'%(i))
    url_assets.append('http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/%s.png'%(i))
df_assets = pd.DataFrame(url_assets)

# %%
df_assets
# Out:
#                                                      0
# 0    http://ddragon.leagueoflegends.com/cdn/10.9.1/...
# 1    http://ddragon.leagueoflegends.com/cdn/10.9.1/...
# 2    http://ddragon.leagueoflegends.com/cdn/10.9.1/...
# 3    http://ddragon.leagueoflegends.com/cdn/10.9.1/...
# 4    http://ddragon.leagueoflegends.com/cdn/10.9.1/...
# ..                                                 ...
# 143  http://ddragon.leagueoflegends.com/cdn/10.9.1/...
# 144  http://ddragon.leagueoflegends.com/cdn/10.9.1/...
# 145  http://ddragon.leagueoflegends.com/cdn/10.9.1/...
# 146  http://ddragon.leagueoflegends.com/cdn/10.9.1/...
# 147  http://ddragon.leagueoflegends.com/cdn/10.9.1/...
#
# [148 rows x 1 columns]

# %%
import glob
import random
import base64
import pandas as pd

from PIL import Image
from io import BytesIO
from IPython.display import HTML

def path_to_image_html(path):
    '''
     This function essentially convert the image url to 
     '<img src="'+ path + '"/>' format. And one can put any
     formatting adjustments to control the height, aspect ratio, size etc.
     within as in the below example. 
    '''

    return '<img src="'+ path + '" style=max-height:124px;"/>'

HTML(df_assets.to_html(escape=False ,formatters=dict(url_assets=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Aatrox.png</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Ahri.png</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Akali.png</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Alistar.png</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Amumu.png</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Anivia.png</td>
#     </tr>
#     <tr>
#       <th>6</th>
# ...

# %%
import pandas as pd
from IPython.core.display import HTML

#df = pd.DataFrame([['A231', 'Book', 5, 3, 150], 
#                   ['M441', 'Magic Staff', 10, 7, 200]],
#                   columns = ['Code', 'Name', 'Price', 'Net', 'Sales'])

#Dataframe
#--------table2

# your images paths
#---------url_assets

#images = ['http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Aatrox.png',
#          'https://i.pinimg.com/originals/d9/5c/9b/d95c9ba809aa9dd4cb519a225af40f2b.png'] 


table3['Image'] = url_assets

# convert your links to html tags 
def path_to_image_html(path):
    return '<img src="'+ path + '" width="20" >'

pd.set_option('display.max_colwidth', -1)

table4 = HTML(table3.to_html(escape=False ,formatters=dict(image=path_to_image_html)))
table4
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Campeón</th>
#       <th>attack</th>
#       <th>defense</th>
#       <th>magic</th>
#       <th>difficulty</th>
#       <th>Popularidad by Skins</th>
#       <th>Rol1</th>
#       <th>Rol2</th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Aatrox-la Espada Darkin.</td>
#       <td>8</td>
#       <td>4</td>
#       <td>3</td>
#       <td>4</td>
#       <td>7</td>
#       <td>Fighter</td>
#       <td>Tank</td>
#       <td>http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Aatrox.png</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ahri-la Vastaya de Nueve Colas.</td>
#       <td>3</td>
#       <td>4</td>
#       <td>8</td>
#       <td>5</td>
#       <td>12</td>
#       <td>Mage</td>
#       <td>Assassin</td>
#       <td>http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Ahri.png</td>
# ...

# %%
table4.to_csv(r'Info_withIMG.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-d2d839bb9b0c> in <module>
# ----> 1 table4.to_csv(r'Info_withIMG.csv')
#
# AttributeError: 'HTML' object has no attribute 'to_csv'

# %%
import pandas as pd
from IPython.core.display import HTML

df = pd.DataFrame([['Aatrox', 8, 4, 'Fighter', 'Tank'], 
                   ['Ahri', 3, 4, 'Mage', 'Assasin']],
                   columns = ['Campeón', 'Attack', 'Defence', 'Rol1', 'Rol2'])

# your images
images = ['http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Aatrox.png',
          'http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Ahri.png'] 


df['image'] = images

# convert your links to html tags 
def path_to_image_html(path):
    return '<img src="'+ path + '" width="50" >'

pd.set_option('display.max_colwidth', -1)

a = HTML(df.to_html(escape=False ,formatters=dict(image=path_to_image_html)))
a
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Campeón</th>
#       <th>Attack</th>
#       <th>Defence</th>
#       <th>Rol1</th>
#       <th>Rol2</th>
#       <th>image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Aatrox</td>
#       <td>8</td>
#       <td>4</td>
#       <td>Fighter</td>
#       <td>Tank</td>
#       <td><img src="http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Aatrox.png" width="50" ></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ahri</td>
#       <td>3</td>
#       <td>4</td>
#       <td>Mage</td>
#       <td>Assasin</td>
#       <td><img src="http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Ahri.png" width="50" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
type(a)
# Out:
# IPython.core.display.HTML

# %%
table2
# Out:
#                                Campeón  attack  defense  magic  difficulty  \
# 0    Aatrox-la Espada Darkin.           8       4        3      4
# 1    Ahri-la Vastaya de Nueve Colas.    3       4        8      5
# 2    Akali-la Asesina Furtiva.          5       3        8      7
# 3    Alistar-el Minotauro.              6       9        5      7
# 4    Amumu-la Momia Triste.             2       6        8      3
# ..                      ...            ..      ..       ..     ..
# 143  Zed-el Maestro de las Sombras.     9       2        1      7
# 144  Ziggs-el Experto en Hexplosivos .  2       4        9      4
# 145  Zilean-el Guardián del Tiempo.     2       5        8      6
# 146  Zoe-el Aspecto del Crepúsculo.     1       7        8      5
# 147  Zyra-el Despertar de las Espinas.  4       3        8      7
#
#      Popularidad by Skins
# 0    7
# 1    12
# 2    13
# 3    14
# 4    11
# ..   ..
# 143  7
# 144  9
# 145  7
# 146  4
# 147  7
#
# [148 rows x 6 columns]

# %%
url_assets[1]
# Out:
# 'http://ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/Ahri.png'

# %%
from IPython.display import display, HTML
 
display(HTML('<h1>Hello, world!</h1>').data)
# Out:
# '<h1>Hello, world!</h1>'
# '<h1>Hello, world!</h1>'
